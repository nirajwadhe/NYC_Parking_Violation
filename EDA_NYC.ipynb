# %%
# Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
df = pd.read_csv(r"F:\End Project\FinalDatasets\Parking_Violations_Issued_-_Fiscal_Year_2023_20240114.csv" , low_memory=False)

# %%
df.shape
# Out:
# (1293558, 43)

# %%
df.info('all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293558 entries, 0 to 1293557
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   Summons Number                     1293558 non-null  object
#  1   Plate ID                           1293533 non-null  object
#  2   Registration State                 1293554 non-null  object
#  3   Plate Type                         1293554 non-null  object
#  4   Issue Date                         1293554 non-null  object
#  5   Violation Code                     1293554 non-null  float64
#  6   Vehicle Body Type                  1290172 non-null  object
#  7   Vehicle Make                       1292195 non-null  object
#  8   Issuing Agency                     1293554 non-null  object
#  9   Street Code1                       1293554 non-null  float64
#  10  Street Code2                       1293554 non-null  float64
# ...

# %%
df.describe(include = 'all')
# Out:
#        Summons Number    Plate ID Registration State Plate Type  Issue Date  \
# count         1293558     1293533            1293554    1293554     1293554
# unique        1293558      778321                 65         70         302
# top        1484697303  BLANKPLATE                 NY        PAS  06/30/2022
# freq                1        1478             967931    1059235       64766
# mean              NaN         NaN                NaN        NaN         NaN
# std               NaN         NaN                NaN        NaN         NaN
# min               NaN         NaN                NaN        NaN         NaN
# 25%               NaN         NaN                NaN        NaN         NaN
# 50%               NaN         NaN                NaN        NaN         NaN
# 75%               NaN         NaN                NaN        NaN         NaN
# max               NaN         NaN                NaN        NaN         NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Summons Number                             0
# Plate ID                                  25
# Registration State                         4
# Plate Type                                 4
# Issue Date                                 4
# Violation Code                             4
# Vehicle Body Type                       3386
# Vehicle Make                            1363
# Issuing Agency                             4
# Street Code1                               4
# Street Code2                               4
# Street Code3                               4
# Vehicle Expiration Date                    4
# Violation Location                    509571
# Violation Precinct                         4
# Issuer Precinct                            4
# Issuer Code                                4
# Issuer Command                        508711
# Issuer Squad                          558825
# Violation Time                            25
# Time First Observed                  1213298
# ...

# %%
df.head()
# Out:
#   Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     1484697303  JER1863                 NY        PAS  06/10/2022
# 1     1484697315  KEV4487                 NY        PAS  06/13/2022
# 2     1484697625   H73NYD                 NJ        PAS  06/19/2022
# 3     1484697674  GJC9296                 NY        PAS  06/19/2022
# 4     1484697686   M51PUV                 NJ        PAS  06/19/2022
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            67.0               SDN        TOYOT              P       34330.0
# 1            51.0              SUBN         JEEP              K       34310.0
# 2            63.0               SDN         JEEP              N       30640.0
# 3            63.0              SUBN        LEXUS              N       30640.0
# 4            63.0               SDN        HYUND              N       30640.0
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Location  \
# ...

# %%
df.tail()
# Out:
#                          Summons Number Plate ID Registration State  \
# 1293553                      9002562615  UCA2019                 VA
# 1293554                  "error" : true      NaN                NaN
# 1293555    "message" : "Internal error"      NaN                NaN
# 1293556                  "status" : 500      NaN                NaN
# 1293557                               }      NaN                NaN
#
#         Plate Type  Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# 1293553        PAS  07/26/2022            21.0              SUBN         AUDI
# 1293554        NaN         NaN             NaN               NaN          NaN
# 1293555        NaN         NaN             NaN               NaN          NaN
# 1293556        NaN         NaN             NaN               NaN          NaN
# 1293557        NaN         NaN             NaN               NaN          NaN
#
#         Issuing Agency  Street Code1  Street Code2  Street Code3  \
# ...

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr(numeric_only = True)
# Out:
#                                    Violation Code  Street Code1  Street Code2  \
# Violation Code                           1.000000      0.106075      0.099190
# Street Code1                             0.106075      1.000000      0.546427
# Street Code2                             0.099190      0.546427      1.000000
# Street Code3                             0.105610      0.556496      0.742235
# Vehicle Expiration Date                  0.079977      0.360939      0.258708
# Violation Location                       0.071448      0.183497      0.154680
# Violation Precinct                       0.173111      0.542964      0.436721
# Issuer Precinct                          0.151492      0.376011      0.300166
# Date First Observed                      0.007295      0.024054      0.021311
# Law Section                             -0.166972     -0.657584     -0.510914
# Unregistered Vehicle?                         NaN           NaN           NaN
# ...

# %%
# Delete Columns with NULL values having thresold below
threshold = len(df)*0.80
df = df.dropna(axis=1, thresh=threshold)

# %%
df.shape
# Out:
# (1293558, 26)

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Precinct', 'Issuer Precinct',
#        'Issuer Code', 'Violation Time', 'Violation County', 'Street Name',
#        'Date First Observed', 'Law Section', 'Sub Division', 'Vehicle Color',
#        'Vehicle Year', 'Feet From Curb', 'Violation Description'],
#       dtype='object')

# %%
# Trim whitespace from column names
df.columns = df.columns.str.strip()

# %%
df['Violation Precinct'].isnull().sum()
# Out:
# 4

# %%
df.head(2)
# Out:
#   Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     1484697303  JER1863                 NY        PAS  06/10/2022
# 1     1484697315  KEV4487                 NY        PAS  06/13/2022
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            67.0               SDN        TOYOT              P       34330.0
# 1            51.0              SUBN         JEEP              K       34310.0
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Precinct  \
# 0         179.0           0.0               20221210.0                10.0
# 1       16400.0       11010.0               20220908.0                10.0
#
#    Issuer Precinct Issuer Code Violation Time Violation County Street Name  \
# 0              1.0      160195          1037A               NY   W 28TH ST
# 1              1.0      160195          1045A               NY     27TH DR
#
# ...

# %%
df.isnull().sum()
# Out:
# Summons Number                 0
# Plate ID                      25
# Registration State             4
# Plate Type                     4
# Issue Date                     4
# Violation Code                 4
# Vehicle Body Type           3386
# Vehicle Make                1363
# Issuing Agency                 4
# Street Code1                   4
# Street Code2                   4
# Street Code3                   4
# Vehicle Expiration Date        4
# Violation Precinct             4
# Issuer Precinct                4
# Issuer Code                    4
# Violation Time                25
# Violation County            4022
# Street Name                  184
# Date First Observed            5
# Law Section                    5
# Sub Division                 255
# Vehicle Color              89014
# Vehicle Year                   5
# Feet From Curb                 5
# Violation Description      32295
# dtype: int64

# %%
df.shape
# Out:
# (1293558, 26)

# %%
# Iterate over columns
for col in df.columns:
    # Check if the column has less than 10000 null values
    if df[col].isnull().sum() < 10000:
        # Drop null rows from that column
        df = df.dropna(subset=[col])

# Now df contains rows with null values dropped from columns with less than 10000 null values

# %%
df.isnull().sum()
# Out:
# Summons Number                 0
# Plate ID                       0
# Registration State             0
# Plate Type                     0
# Issue Date                     0
# Violation Code                 0
# Vehicle Body Type              0
# Vehicle Make                   0
# Issuing Agency                 0
# Street Code1                   0
# Street Code2                   0
# Street Code3                   0
# Vehicle Expiration Date        0
# Violation Precinct             0
# Issuer Precinct                0
# Issuer Code                    0
# Violation Time                 0
# Violation County               0
# Street Name                    0
# Date First Observed            0
# Law Section                    0
# Sub Division                   0
# Vehicle Color              87014
# Vehicle Year                   0
# Feet From Curb                 0
# Violation Description      26520
# dtype: int64

# %%
df['Vehicle Color'].describe()
# Out:
# count     1198557
# unique        452
# top            GY
# freq       250105
# Name: Vehicle Color, dtype: object

# %%
df['Violation Description'].describe()
# Out:
# count                            1259051
# unique                               137
# top       PHTO SCHOOL ZN SPEED VIOLATION
# freq                              389882
# Name: Violation Description, dtype: object

# %%
df.loc[:, 'Vehicle Color'] = df['Vehicle Color'].fillna(df['Vehicle Color'].mode().iloc[0])
df.loc[:, 'Violation Description'] = df['Violation Description'].fillna(df['Violation Description'].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Summons Number             0
# Plate ID                   0
# Registration State         0
# Plate Type                 0
# Issue Date                 0
# Violation Code             0
# Vehicle Body Type          0
# Vehicle Make               0
# Issuing Agency             0
# Street Code1               0
# Street Code2               0
# Street Code3               0
# Vehicle Expiration Date    0
# Violation Precinct         0
# Issuer Precinct            0
# Issuer Code                0
# Violation Time             0
# Violation County           0
# Street Name                0
# Date First Observed        0
# Law Section                0
# Sub Division               0
# Vehicle Color              0
# Vehicle Year               0
# Feet From Curb             0
# Violation Description      0
# dtype: int64

# %%
df['Violation Description'].value_counts().head(50)
# Out:
# Violation Description
# PHTO SCHOOL ZN SPEED VIOLATION    416402
# 21-No Parking (street clean)      141232
# 38-Failure to Dsplay Meter Rec     79791
# 14-No Standing                     66651
# FAILURE TO STOP AT RED LIGHT       59169
# BUS LANE VIOLATION                 52742
# 40-Fire Hydrant                    48889
# No Parking Street Cleaning         45254
# 71A-Insp Sticker Expired (NYS)     44420
# 20A-No Parking (Non-COM)           41274
# 70A-Reg. Sticker Expired (NYS)     29811
# 31-No Stand (Com. Mtr. Zone)       21121
# 19-No Stand (bus stop)             20713
# 37-Expired Parking Meter           19733
# 69-Fail to Dsp Prking Mtr Rcpt     18954
# 20-No Parking (Com Plate)          17315
# 16A-No Std (Com Veh) Non-COM       15792
# 46A-Double Parking (Non-COM)       14080
# 74A-Improperly Displayed Plate     10095
# 74-Missing Display Plate            9767
# 46B-Double Parking (Com-100Ft)      9114
# 47-Double PKG-Midtown(Com Veh)      8595
# ...

# %%
df.head(1)
# Out:
#   Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     1484697303  JER1863                 NY        PAS  06/10/2022
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            67.0               SDN        TOYOT              P       34330.0
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Precinct  \
# 0         179.0           0.0               20221210.0                10.0
#
#    Issuer Precinct Issuer Code Violation Time Violation County Street Name  \
# 0              1.0      160195          1037A               NY   W 28TH ST
#
#    Date First Observed  Law Section Sub Division Vehicle Color  Vehicle Year  \
# 0                  0.0        408.0           E3           BLK        2004.0
#
#    Feet From Curb           Violation Description
# 0             0.0  PHTO SCHOOL ZN SPEED VIOLATION

# %%
df['Violation Time'] = df['Violation Time'] + 'M'

# %%
df.head(1)
# Out:
#   Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     1484697303  JER1863                 NY        PAS  06/10/2022
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            67.0               SDN        TOYOT              P       34330.0
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Precinct  \
# 0         179.0           0.0               20221210.0                10.0
#
#    Issuer Precinct Issuer Code Violation Time Violation County Street Name  \
# 0              1.0      160195         1037AM               NY   W 28TH ST
#
#    Date First Observed  Law Section Sub Division Vehicle Color  Vehicle Year  \
# 0                  0.0        408.0           E3           BLK        2004.0
#
#    Feet From Curb           Violation Description
# 0             0.0  PHTO SCHOOL ZN SPEED VIOLATION

# %%
df['Violation Time'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0          1037AM
# 1          1045AM
# 2          1116AM
# 3          1052AM
# 4          1107AM
#             ...
# 1293548    0732AM
# 1293549    0734AM
# 1293550    0737AM
# 1293551    0741AM
# 1293552    0743AM
# Name: Violation Time, Length: 1285571, dtype: object>

# %%
# Convert the time column to 'hh:mm AM/PM' format
df['Violation Time'] = df['Violation Time'].str[:2] + ':' + df['Violation Time'].str[2:4] + ' ' + df['Violation Time'].str[4:]

# %%
df['Violation Time'].head(10)
# Out:
# 0     10:37 AM
# 1     10:45 AM
# 2     11:16 AM
# 3     10:52 AM
# 4     11:07 AM
# 7     12:05 PM
# 8     05:35 PM
# 9     03:07 PM
# 10    02:25 PM
# 11    03:20 PM
# Name: Violation Time, dtype: object

# %%
# Convert 'Time' column to datetime format
# df['Violation Time'] = pd.to_datetime(df['Violation Time']).dt.time

# %%
df['Plate Type'].unique()
# Out:
# array(['PAS', 'OMS', '999', 'OMT', 'SRF', 'COM', 'MED', 'ORG', 'MOT',
#        'TRL', 'HIS', 'SPO', 'MCL', 'NYS', 'RGL', 'VPL', 'OMV', 'OML',
#        'VAS', 'HIR', 'PSD', 'HAM', 'TOW', 'SOS', 'PHS', 'JSC', 'ITP',
#        'CMB', 'AGC', 'NLM', 'NYC', 'CSP', 'TRC', 'OMR', 'SEM', 'APP',
#        'SRN', 'LMB', 'SCL', 'IRP', 'DLR', 'NYA', 'CHC', 'STA', 'TRA',
#        'LTR', 'RGC', 'ORC', 'ARG', 'SPC', 'LMA', 'SUP', 'ATV', 'AYG',
#        'AMB', 'BOB', 'AGR', 'STG', 'CLG', 'CME', 'LMC', 'OMO', 'FAR',
#        'CBS', 'JCA', 'MCD', 'CCK', 'CMH', 'PPH'], dtype=object)

# %%
len(df[df['Plate Type']=='999'])
# Checking the length of Plate Type '999' ,
# Out:
# 5559

# %%
df = df[df['Plate Type'] != '999']

# %%
df['Plate Type'].unique()
# Out:
# array(['PAS', 'OMS', 'OMT', 'SRF', 'COM', 'MED', 'ORG', 'MOT', 'TRL',
#        'HIS', 'SPO', 'MCL', 'NYS', 'RGL', 'VPL', 'OMV', 'OML', 'VAS',
#        'HIR', 'PSD', 'HAM', 'TOW', 'SOS', 'PHS', 'JSC', 'ITP', 'CMB',
#        'AGC', 'NLM', 'NYC', 'CSP', 'TRC', 'OMR', 'SEM', 'APP', 'SRN',
#        'LMB', 'SCL', 'IRP', 'DLR', 'NYA', 'CHC', 'STA', 'TRA', 'LTR',
#        'RGC', 'ORC', 'ARG', 'SPC', 'LMA', 'SUP', 'ATV', 'AYG', 'AMB',
#        'BOB', 'AGR', 'STG', 'CLG', 'CME', 'LMC', 'OMO', 'FAR', 'CBS',
#        'JCA', 'MCD', 'CCK', 'CMH', 'PPH'], dtype=object)

# %%
df['Plate Type'].value_counts()
# Out:
# Plate Type
# PAS    1052435
# COM     129418
# OMT      43192
# SRF      14726
# OMS      12280
# APP       4440
# MOT       3804
# LMB       3273
# ORG       2828
# SPO       1988
# MED       1697
# TRC       1510
# OMR       1134
# CMB       1120
# PSD        936
# SCL        737
# RGL        719
# TOW        529
# OML        452
# VAS        436
# ITP        435
# TRL        296
# IRP        253
# SRN        237
# DLR        195
# HIS        165
# MCL        108
# TRA         88
# NYC         63
# STA         62
# AMB         56
# ORC         50
# PHS         46
# SPC         37
# AGR         32
# NYS         28
# OMV         27
# LMA         19
# CHC         17
# SOS         14
# HAM         13
# AYG         11
# ATV         11
# CSP         11
# BOB         10
# RGC         10
# STG          8
# NLM          7
# CBS          6
# MCD          5
# SUP          5
# CMH          4
# LTR          4
# AGC          3
# SEM          3
# ARG          3
# VPL          2
# NYA          2
# ...

# %%
df['Registration State'].value_counts()
# Out:
# Registration State
# NY    962449
# NJ    112949
# PA     42000
# FL     29643
# CT     19987
# IN     11376
# GA     10080
# TX      9251
# VA      9026
# MA      8441
# NC      7855
# MD      7483
# CA      5412
# IL      4154
# AZ      4012
# OH      3997
# SC      3248
# ME      2685
# DE      2190
# TN      1848
# AL      1810
# MN      1704
# MI      1618
# WA      1547
# VT      1406
# RI      1272
# NH      1140
# OK       978
# CO       840
# WI       820
# MS       780
# MO       736
# OR       665
# ON       646
# 99       633
# KY       580
# LA       474
# WV       427
# QB       407
# SD       405
# DC       396
# AR       358
# NV       301
# MT       260
# IA       231
# UT       201
# NM       190
# GV       181
# KS       173
# NE       165
# DP       137
# ID       120
# WY        67
# ND        59
# AK        53
# HI        45
# PR        35
# NS        21
# AB        15
# NB        14
# BC         9
# MB         3
# PE         2
# SK         1
# FO         1
# ...

# %%
df['Issue Date'].unique()
# Out:
# array(['06/10/2022', '06/13/2022', '06/19/2022', '06/20/2022',
#        '06/25/2022', '06/05/2022', '06/19/2023', '06/09/2022',
#        '06/30/2022', '07/03/2022', '06/18/2022', '06/29/2022',
#        '07/04/2022', '07/09/2022', '06/15/2022', '06/11/2022',
#        '06/17/2022', '06/04/2022', '07/05/2022', '06/26/2022',
#        '06/06/2022', '06/08/2022', '06/22/2022', '07/02/2022',
#        '06/14/2022', '06/23/2022', '06/24/2022', '06/27/2022',
#        '06/21/2022', '06/12/2022', '07/10/2022', '07/06/2022',
#        '07/07/2022', '04/29/2022', '05/28/2022', '06/02/2022',
#        '06/01/2022', '07/01/2022', '06/16/2022', '05/11/2022',
#        '04/01/2022', '05/29/2022', '05/03/2022', '06/20/2021',
#        '06/28/2022', '06/03/2022', '05/05/2022', '07/08/2022',
#        '06/07/2022', '05/22/2022', '05/13/2022', '07/11/2022',
#        '06/25/2021', '07/12/2022', '05/30/2022', '05/31/2022',
#        '06/23/2021', '04/21/2022', '03/15/2022', '02/07/2022',
# ...

# %%
df['Issue Date'] = pd.to_datetime(df['Issue Date'])
df_sorted = df.sort_values(by = 'Issue Date')

# %%
df_sorted.head()
# Out:
#         Summons Number Plate ID Registration State Plate Type Issue Date  \
# 3873        1486052228   KXFB52                 FL        PAS 2000-06-28
# 7040        1487623604  KKP7984                 NY        PAS 2000-07-09
# 1174358     1472943545  KXU6330                 NY        PAS 2000-08-01
# 8505        1487960633  KVT4495                 NY        PAS 2012-06-24
# 3060        1476136660  GZE2213                 NY        PAS 2014-06-12
#
#          Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 3873               99.0               SDN          KIA              P
# 7040               40.0               SDN        TOYOT              P
# 1174358            98.0               SDN        HONDA              P
# 8505               46.0              SUBN        ACURA              P
# 3060               17.0               SDN        CADIL              P
#
#          Street Code1  Street Code2  Street Code3  Vehicle Expiration Date  \
# ...

# %%
df_sorted.tail()
# Out:
#        Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 9219       1488079420   KUW3249                 NY        PAS 2027-07-01
# 396764     1452057631    J10PTN                 NJ        PAS 2027-07-09
# 425306     1488411190  T800334C                 NY        OMT 2031-06-28
# 435356     1487877730   42687C8                 TX        PAS 2049-07-07
# 435392     1487879672    2BA285                 SD        PAS 2066-06-24
#
#         Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 9219              98.0               SDN         FORD              P
# 396764            99.0              SUBN          GMC              N
# 425306            40.0               SDN        NISSA              P
# 435356            40.0               SDN        CHEVR              P
# 435392            14.0              SUBN         FORD              P
#
#         Street Code1  Street Code2  Street Code3  Vehicle Expiration Date  \
# ...

# %%
# df['Issue Date'] = pd.to_datetime(df['Issue Date'])
df['Issue Year'] = df['Issue Date'].dt.year
df['Issue Month'] = df['Issue Date'].dt.month

# %%
df.head(1)
# Out:
#   Summons Number Plate ID Registration State Plate Type Issue Date  \
# 0     1484697303  JER1863                 NY        PAS 2022-06-10
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            67.0               SDN        TOYOT              P       34330.0
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Precinct  \
# 0         179.0           0.0               20221210.0                10.0
#
#    Issuer Precinct Issuer Code Violation Time Violation County Street Name  \
# 0              1.0      160195       10:37 AM               NY   W 28TH ST
#
#    Date First Observed  Law Section Sub Division Vehicle Color  Vehicle Year  \
# 0                  0.0        408.0           E3           BLK        2004.0
#
#    Feet From Curb           Violation Description  Issue Year  Issue Month
# 0             0.0  PHTO SCHOOL ZN SPEED VIOLATION        2022            6

# %%
df['Issue Year'].max() , '&' , df['Issue Year'].min()
# Out:
# (2066, '&', 2000)

# %%
df['Issue Year'].value_counts()
# Out:
# Issue Year
# 2022    1279863
# 2021         61
# 2023         55
# 2020         14
# 2027          6
# 2000          3
# 2025          2
# 2024          1
# 2014          1
# 2026          1
# 2012          1
# 2018          1
# 2031          1
# 2049          1
# 2066          1
# Name: count, dtype: int64

# %%
# Filter rows where 'Issue Year' is between 2020 and 2024
df = df[(df['Issue Year'] >= 2020) & (df['Issue Year'] <= 2024)]

# %%
df['Issue Year'].value_counts()
# Out:
# Issue Year
# 2022    1279863
# 2021         61
# 2023         55
# 2020         14
# 2024          1
# Name: count, dtype: int64

# %%
df['Issue Month'].value_counts()
# Out:
# Issue Month
# 7     981794
# 6     297150
# 5        666
# 4        165
# 8        119
# 3         64
# 10        11
# 2          9
# 9          4
# 12         4
# 1          4
# 11         4
# Name: count, dtype: int64

# %%
df[df['Issue Year']==2020]['Issue Month'].value_counts().sort_index()
# Out:
# Issue Month
# 6    11
# 7     3
# Name: count, dtype: int64

# %%
# df.groupby(['Issue Month']).count()['Issue Year'].sort_values(ascending=False).reset_index().head(5)

# %%
# df[df['Issue Year']==2020]['Issue Month']==6

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Precinct', 'Issuer Precinct',
#        'Issuer Code', 'Violation Time', 'Violation County', 'Street Name',
#        'Date First Observed', 'Law Section', 'Sub Division', 'Vehicle Color',
#        'Vehicle Year', 'Feet From Curb', 'Violation Description', 'Issue Year',
#        'Issue Month'],
#       dtype='object')

# %%
kk = df['Violation Time'].str[:2].astype(int)

# %%
# Filter values between 1 and 12
df = df[(kk >= 1) & (kk <= 12)]

# %%
df['Violation Code'].nunique()
# Out:
# 89

# %%
df['Violation Code'].unique()
# Out:
# array([67., 51., 63., 98., 10., 45., 14., 20., 68., 27., 53., 19., 40.,
#        74., 16., 17., 48., 62., 70., 46., 50., 71., 21., 24., 41., 99.,
#        75., 83., 18., 37., 38., 78., 97., 61., 91., 96., 52., 13., 11.,
#        39., 54., 49.,  5., 31., 60., 90., 95.,  6., 92., 89., 85., 55.,
#        56.,  9., 66., 80., 36., 72., 22., 26.,  7., 69., 12., 87., 33.,
#        73., 76., 79., 82., 64., 25.,  4., 47., 42., 35., 84., 32.,  8.,
#        77., 58., 23., 65., 34., 57., 81., 44., 59.,  1., 29.])

# %%
df['Violation Time'] = pd.to_datetime(df['Violation Time']).dt.time
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8116\3994287525.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Violation Time'] = pd.to_datetime(df['Violation Time']).dt.time
# C:\Users\hp\AppData\Local\Temp\ipykernel_8116\3994287525.py:1: FutureWarning: Parsed string "12:58 M" included an un-recognized timezone "M". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df['Violation Time'] = pd.to_datetime(df['Violation Time']).dt.time
# ...

# %%
df.tail()
# Out:
#         Summons Number Plate ID Registration State Plate Type Issue Date  \
# 1293548     9002562561   24BJSW                 FL        PAS 2022-07-26
# 1293549     9002562573   24BJSW                 FL        PAS 2022-07-26
# 1293550     9002562585  KSZ6687                 NY        PAS 2022-07-26
# 1293551     9002562597  HMV9474                 NY        PAS 2022-07-26
# 1293552     9002562603  KVD5533                 NY        PAS 2022-07-26
#
#          Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 1293548            74.0              SUBN         FORD              T
# 1293549            14.0              SUBN         FORD              T
# 1293550            40.0              SUBN        TOYOT              T
# 1293551            21.0              4DSD        TOYOT              T
# 1293552            21.0              SUBN        HONDA              T
#
#          Street Code1  Street Code2  Street Code3  Vehicle Expiration Date  \
# ...

# %%
df['Violation Time'].head(100)
# Out:
# 0      10:37:00
# 1      10:45:00
# 2      11:16:00
# 3      10:52:00
# 4      11:07:00
# 7      12:05:00
# 8      17:35:00
# 9      15:07:00
# 10     14:25:00
# 11     15:20:00
# 12     11:02:00
# 13     18:06:00
# 14     12:50:00
# 15     10:31:00
# 16     11:32:00
# 17     11:35:00
# 18     18:07:00
# 19     19:12:00
# 20     14:35:00
# 21     13:56:00
# 23     18:26:00
# 24     20:41:00
# 25     18:13:00
# 26     09:40:00
# 27     11:51:00
# 28     12:21:00
# 29     12:20:00
# 30     15:50:00
# 31     09:22:00
# 32     14:14:00
# 33     04:30:00
# 35     04:40:00
# 36     04:45:00
# 37     04:49:00
# 40     12:48:00
# 42     17:37:00
# 44     19:44:00
# 46     14:22:00
# 47     10:23:00
# 48     10:30:00
# 49     12:23:00
# 50     11:09:00
# 51     08:32:00
# 52     09:02:00
# 53     09:50:00
# 55     13:00:00
# 56     16:34:00
# 57     16:30:00
# 58     04:53:00
# 59     16:55:00
# 60     10:45:00
# 62     09:15:00
# 63     09:51:00
# 65     20:41:00
# 66     21:58:00
# ...

# %%
df['Violation Code'] = df['Violation Code'].astype(int)

# %%
df.dtypes
# Out:
# Summons Number                     object
# Plate ID                           object
# Registration State                 object
# Plate Type                         object
# Issue Date                 datetime64[ns]
# Violation Code                      int32
# Vehicle Body Type                  object
# Vehicle Make                       object
# Issuing Agency                     object
# Street Code1                      float64
# Street Code2                      float64
# Street Code3                      float64
# Vehicle Expiration Date           float64
# Violation Precinct                float64
# Issuer Precinct                   float64
# Issuer Code                        object
# Violation Time                     object
# Violation County                   object
# Street Name                        object
# Date First Observed               float64
# Law Section                       float64
# Sub Division                       object
# ...

# %%
# Filtered the 99 from Registration State as it is wrong type of Data contain
df = df[df['Registration State']!='99']
