# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("F:/End Project/FinalDatasets/Parking_Violations_Issued_-_Fiscal_Year_2022_20240115.csv" , low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df = pd.read_csv("F:/End Project/FinalDatasets/Parking_Violations_Issued_-_Fiscal_Year_2022_20240115.csv" , low_memory=False)
#
# ...

# %%
df.shape
# Out:
# (8943062, 43)

# %%
df.head()
# Out:
#   Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0     1457617912   JEB5683                 NY        PAS  06/25/2021
# 1     1457617924   JAN2986                 NY        PAS  06/25/2021
# 2     1457622427   FJH6630                 TX        PAS  06/17/2021
# 3     1457638629    RD1Y5N                 MO        PAS  06/16/2021
# 4     1457639580  T503814C                 NY        OMT  07/04/2021
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            40.0               VAN         FORD              P       63430.0
# 1            20.0              SUBN        DODGE              P       13490.0
# 2            98.0               SDN         AUDI              P       79430.0
# 3            98.0               SDN        TOYOT              P       53130.0
# 4            40.0              TAXI        HONDA              P       81030.0
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# ...

# %%
df.isnull().sum()
# Out:
# Summons Number                             0
# Plate ID                                 110
# Registration State                         4
# Plate Type                                 4
# Issue Date                                 4
# Violation Code                             4
# Vehicle Body Type                      19543
# Vehicle Make                            6314
# Issuing Agency                             4
# Street Code1                               4
# Street Code2                               4
# Street Code3                               4
# Vehicle Expiration Date                    4
# Violation Location                   3703196
# Violation Precinct                         4
# Issuer Precinct                            4
# Issuer Code                                4
# Issuer Command                       3700246
# Issuer Squad                         3907896
# Violation Time                           105
# Time First Observed                  8518588
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
pd.set_option('display.max_columns', 1000)

# %%
df.dtypes
# Out:
# Summons Number                        object
# Plate ID                              object
# Registration State                    object
# Plate Type                            object
# Issue Date                            object
# Violation Code                       float64
# Vehicle Body Type                     object
# Vehicle Make                          object
# Issuing Agency                        object
# Street Code1                         float64
# Street Code2                         float64
# Street Code3                         float64
# Vehicle Expiration Date              float64
# Violation Location                   float64
# Violation Precinct                   float64
# Issuer Precinct                      float64
# Issuer Code                          float64
# Issuer Command                        object
# Issuer Squad                          object
# Violation Time                        object
# Time First Observed                   object
# ...

# %%
df.head()
# Out:
#   Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0     1457617912   JEB5683                 NY        PAS  06/25/2021
# 1     1457617924   JAN2986                 NY        PAS  06/25/2021
# 2     1457622427   FJH6630                 TX        PAS  06/17/2021
# 3     1457638629    RD1Y5N                 MO        PAS  06/16/2021
# 4     1457639580  T503814C                 NY        OMT  07/04/2021
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            40.0               VAN         FORD              P       63430.0
# 1            20.0              SUBN        DODGE              P       13490.0
# 2            98.0               SDN         AUDI              P       79430.0
# 3            98.0               SDN        TOYOT              P       53130.0
# 4            40.0              TAXI        HONDA              P       81030.0
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Location  \
# ...

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
# ...

# %%
# Delete Columns with NULL values having thresold below
threshold = len(df)*0.80
cleaned_df = df.dropna(axis=1, thresh=threshold)

# %%
cleaned_df.shape
# Out:
# (8943062, 26)

# %%
cleaned_df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Precinct', 'Issuer Precinct',
#        'Issuer Code', 'Violation Time', 'Violation County', 'Street Name',
#        'Date First Observed', 'Law Section', 'Sub Division', 'Vehicle Color',
#        'Vehicle Year', 'Feet From Curb', 'Violation Description'],
#       dtype='object')

# %%
df.shape
# Out:
# (8943062, 43)

# %%
df = cleaned_df

# %%
df.corr(numeric_only = True)
# Out:
#                          Violation Code  Street Code1  Street Code2  \
# Violation Code                 1.000000      0.128380      0.125795
# Street Code1                   0.128380      1.000000      0.535568
# Street Code2                   0.125795      0.535568      1.000000
# Street Code3                   0.129754      0.544645      0.741512
# Vehicle Expiration Date        0.081151      0.384717      0.276725
# Violation Precinct             0.200813      0.548109      0.431021
# Issuer Precinct                0.158921      0.392875      0.312908
# Issuer Code                    0.219160      0.608666      0.487966
# Date First Observed            0.007152      0.029200      0.023113
# Law Section                   -0.189303     -0.665429     -0.512078
# Vehicle Year                   0.012806     -0.258311     -0.194200
# Feet From Curb                 0.041201      0.064620      0.034208
#
#                          Street Code3  Vehicle Expiration Date  \
# ...

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
df['Violation Code'].unique()
# Out:
# array([40., 20., 98., 70., 74., 21., 24., 14., 67., 19., 78., 51., 46.,
#        61., 33., 27., 68., 50., 10., 85., 83., 17., 23., 63., 39., 53.,
#        16., 54., 45., 36., 48., 99., 41., 66., 91., 75., 71.,  6., 96.,
#        62.,  4., 31.,  9., 97., 35., 18., 60., 38., 11., 52.,  5., 95.,
#        79., 87., 80., 22., 37., 13., 69., 47., 84., 49., 82., 73., 90.,
#        56., 26., 64., 77.,  0., 94., 72.,  7., 12., 42., 76.,  8., 59.,
#        25., 32., 30., 89.,  1., 92., 44.,  3., 58., 55.,  2., 34., 93.,
#        65., 29., 28., 43., 81., nan])

# %%
pd.set_option('display.max_rows', None)
df['Violation Code'].value_counts()
# Out:
# Violation Code
# 36.0    2862235
# 21.0     890801
# 38.0     579053
# 14.0     529663
# 40.0     467305
# 5.0      438210
# 20.0     431668
# 71.0     385037
# 7.0      368820
# 70.0     245110
# 46.0     198054
# 19.0     167309
# 37.0     148543
# 31.0     146215
# 74.0     145802
# 16.0     143533
# 69.0     111794
# 17.0      84550
# 47.0      61573
# 50.0      59202
# 48.0      42409
# 10.0      42287
# 84.0      41020
# 51.0      35396
# 98.0      35316
# 53.0      31093
# 12.0      30983
# 18.0      23279
# 42.0      20188
# 78.0      17363
# 82.0      16708
# 66.0      14516
# 68.0      13378
# 13.0      13266
# 61.0      11882
# 75.0      10137
# 72.0       6981
# 64.0       6422
# 22.0       6156
# 9.0        4760
# 76.0       4617
# 85.0       4149
# 33.0       4096
# 11.0       3887
# 83.0       3738
# 67.0       3620
# 73.0       2992
# 62.0       2666
# 60.0       2202
# 4.0        2017
# 99.0       1686
# 27.0       1682
# 77.0       1579
# 80.0       1499
# ...

# %%
df['Violation Code'].isnull().sum()
# Out:
# 4

# %%
df.loc[:, 'Violation Code'] = df['Violation Code'].fillna(df['Violation Code'].mode().iloc[0])

# %%
df['Violation Code'].isnull().sum()
# Out:
# 0

# %%
df['Violation Code'].describe()
# Out:
# count    8.943062e+06
# mean     3.388571e+01
# std      1.846551e+01
# min      0.000000e+00
# 25%      2.000000e+01
# 50%      3.600000e+01
# 75%      3.800000e+01
# max      9.900000e+01
# Name: Violation Code, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(numeric_only = True),annot=True, annot_kws={'size':7})
plt.show()

# %%
df.isnull().sum()
# Out:
# Summons Number                  0
# Plate ID                      110
# Registration State              4
# Plate Type                      4
# Issue Date                      4
# Violation Code                  0
# Vehicle Body Type           19543
# Vehicle Make                 6314
# Issuing Agency                  4
# Street Code1                    4
# Street Code2                    4
# Street Code3                    4
# Vehicle Expiration Date         4
# Violation Precinct              4
# Issuer Precinct                 4
# Issuer Code                     4
# Violation Time                105
# Violation County            20157
# Street Name                   799
# Date First Observed             5
# Law Section                     5
# Sub Division                 1121
# Vehicle Color              621781
# Vehicle Year                    5
# Feet From Curb                  5
# Violation Description      177813
# dtype: int64

# %%
df.shape
# Out:
# (8943062, 26)

# %%
df['Issue Date'].unique()
# Out:
# array(['06/25/2021', '06/17/2021', '06/16/2021', '07/04/2021',
#        '06/28/2021', '07/02/2021', '06/19/2021', '07/03/2021',
#        '07/08/2021', '07/06/2021', '06/27/2021', '06/23/2021',
#        '06/30/2021', '07/01/2021', '06/18/2021', '07/10/2021',
#        '07/22/2021', '07/23/2021', '06/29/2021', '06/24/2021',
#        '07/05/2021', '07/09/2021', '07/19/2021', '07/12/2021',
#        '07/16/2021', '07/13/2021', '07/15/2021', '07/21/2021',
#        '07/20/2021', '07/17/2021', '07/14/2021', '06/22/2021',
#        '07/07/2021', '06/26/2021', '06/20/2021', '07/24/2021',
#        '07/18/2021', '06/21/2021', '07/11/2021', '07/04/2020',
#        '06/14/2021', '06/13/2021', '06/11/2021', '07/25/2021',
#        '11/10/2020', '11/18/2020', '11/24/2020', '11/25/2020',
#        '12/01/2020', '12/09/2020', '10/29/2020', '11/06/2020',
#        '06/07/2021', '07/18/2022', '07/01/2031', '06/10/2021',
#        '06/15/2021', '06/09/2021', '06/08/2021', '05/28/2021',
# ...

# %%
df_sorted = df.sort_values(by = 'Issue Date')

# %%
df_sorted.head()
# Out:
#         Summons Number    Plate ID Registration State Plate Type  Issue Date  \
# 7848477     1481844520      G25DKW                 NJ        PAS  01/01/2021
# 8261242     1483861340  BLANKPLATE                 99        999  01/01/2021
# 8242143     1485186511      D86LAC                 NJ        PAS  01/01/2021
# 8240037     1476120316     KMB3198                 NY        PAS  01/01/2021
# 4393964     1473812793      N82MTT                 NJ        PAS  01/01/2021
#
#          Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 7848477            98.0              SUBN        TOYOT              P
# 8261242            74.0               SDN        INFIN              P
# 8242143            96.0               SDN        HYUND              P
# 8240037            21.0              SUBN        NISSA              P
# 4393964            40.0              SUBN        NISSA              P
#
#          Street Code1  Street Code2  Street Code3  Vehicle Expiration Date  \
# ...

# %%
df_sorted.tail(20)
# Out:
#                          Summons Number Plate ID Registration State  \
# 8047853                      5118878664  HHA7017                 NY
# 8047854                      5118878676  JRS9640                 NY
# 8047855                      5118878690  JNR1920                 NY
# 8047856                      5118878718  JEA3729                 NY
# 8047857                      5118878720  KPL4134                 NY
# 8047858                      5118878767  KMK1753                 NY
# 8047860                      5118878792  JMY5404                 NY
# 8047861                      5118878809  HHU2449                 NY
# 8047862                      5118878810  GZY2911                 NY
# 8047863                      5118878822  GKZ8502                 NY
# 8047864                      5118878846  KPZ2953                 NY
# 8047865                      5118878860  KNW5182                 NY
# 8047859                      5118878780  KTW9050                 NY
# ...

# %%
df['Issue Date'].isnull().sum()
# Out:
# 4

# %%
df.dropna(subset=['Issue Date'], inplace=True)
# Dropping Null values which date is not avilable

# %%
df['Issue Date'].isnull().sum()
# Out:
# 0

# %%
df.tail()
# Out:
#         Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 8943053     8993274848   12215MM                 NY        COM  01/05/2022
# 8943054     8993274850    USR539                 SC        PAS  01/05/2022
# 8943055     8993274861   ASW7166                 NY        PAS  01/05/2022
# 8943056     8978991609  T781042C                 NY        OMT  01/25/2022
# 8943057     8978991610    T10ELM                 NJ        PAS  01/25/2022
#
#          Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 8943053            38.0              PICK         FORD              T
# 8943054            14.0              4DSD        LINCO              T
# 8943055            14.0              SUBN         FORD              T
# 8943056            20.0              4DSD        NISSA              T
# 8943057            20.0              4DSD        LINCO              T
#
#          Street Code1  Street Code2  Street Code3  Vehicle Expiration Date  \
# ...

# %%
df['Issue Date'].unique()
# Out:
# array(['06/25/2021', '06/17/2021', '06/16/2021', '07/04/2021',
#        '06/28/2021', '07/02/2021', '06/19/2021', '07/03/2021',
#        '07/08/2021', '07/06/2021', '06/27/2021', '06/23/2021',
#        '06/30/2021', '07/01/2021', '06/18/2021', '07/10/2021',
#        '07/22/2021', '07/23/2021', '06/29/2021', '06/24/2021',
#        '07/05/2021', '07/09/2021', '07/19/2021', '07/12/2021',
#        '07/16/2021', '07/13/2021', '07/15/2021', '07/21/2021',
#        '07/20/2021', '07/17/2021', '07/14/2021', '06/22/2021',
#        '07/07/2021', '06/26/2021', '06/20/2021', '07/24/2021',
#        '07/18/2021', '06/21/2021', '07/11/2021', '07/04/2020',
#        '06/14/2021', '06/13/2021', '06/11/2021', '07/25/2021',
#        '11/10/2020', '11/18/2020', '11/24/2020', '11/25/2020',
#        '12/01/2020', '12/09/2020', '10/29/2020', '11/06/2020',
#        '06/07/2021', '07/18/2022', '07/01/2031', '06/10/2021',
#        '06/15/2021', '06/09/2021', '06/08/2021', '05/28/2021',
# ...

# %%
df_sorted_date = df.sort_values(by = 'Issue Date')

# %%
df_sorted_date.tail()
# Out:
#         Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 8047865     5118878860  KNW5182                 NY        PAS  12/31/2021
# 8047859     5118878780  KTW9050                 NY        PAS  12/31/2021
# 8707139     8857002299  KDD4533                 NY        PAS  12/31/2021
# 7855945     1486576047  LSS2761                 PA        PAS  12/31/2022
# 7848581     1472666021  JRN1611                 NY        PAS  12/31/2031
#
#          Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 8047865             7.0              SUBN         JEEP              V
# 8047859             7.0              4DSD        HONDA              V
# 8707139            19.0              4DSD        NISSA              T
# 7855945            40.0               SDN         FORD              P
# 7848581            40.0              SUBN        ROVER              P
#
#          Street Code1  Street Code2  Street Code3  Vehicle Expiration Date  \
# ...

# %%
df['Issue Date'] = pd.to_datetime(df['Issue Date'])
df['Issue Year'] = df['Issue Date'].dt.year
df['Issue Month'] = df['Issue Date'].dt.month

# %%
df.head()
# Out:
#   Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 0     1457617912   JEB5683                 NY        PAS 2021-06-25
# 1     1457617924   JAN2986                 NY        PAS 2021-06-25
# 2     1457622427   FJH6630                 TX        PAS 2021-06-17
# 3     1457638629    RD1Y5N                 MO        PAS 2021-06-16
# 4     1457639580  T503814C                 NY        OMT 2021-07-04
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0            40.0               VAN         FORD              P       63430.0
# 1            20.0              SUBN        DODGE              P       13490.0
# 2            98.0               SDN         AUDI              P       79430.0
# 3            98.0               SDN        TOYOT              P       53130.0
# 4            40.0              TAXI        HONDA              P       81030.0
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Precinct  \
# ...

# %%
df.dropna(subset=['Violation Time'], inplace=True)
# Dropping Null values which date is not avilable

# %%
# df['Violation Time'] = pd.to_datetime(df['Violation Time'], format='mixed').dt.strftime('%I:%M:%S %p')

# %%
print(df['Issue Year'].max() , '&' , df['Issue Year'].min())
# Out:
# 2067 & 1973

# %%
df['Violation Code'].unique()
# Out:
# array([40., 20., 98., 70., 74., 21., 24., 14., 67., 19., 78., 51., 46.,
#        61., 33., 27., 68., 50., 10., 85., 83., 17., 23., 63., 39., 53.,
#        16., 54., 45., 36., 48., 99., 41., 66., 91., 75., 71.,  6., 96.,
#        62.,  4., 31.,  9., 97., 35., 18., 60., 38., 11., 52.,  5., 95.,
#        79., 87., 80., 22., 37., 13., 69., 47., 84., 49., 82., 73., 90.,
#        56., 26., 64., 77.,  0., 94., 72.,  7., 12., 42., 76.,  8., 59.,
#        25., 32., 30., 89.,  1., 92., 44.,  3., 58., 55.,  2., 34., 93.,
#        65., 29., 28., 43., 81.])

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Precinct', 'Issuer Precinct',
#        'Issuer Code', 'Violation Time', 'Violation County', 'Street Name',
#        'Date First Observed', 'Law Section', 'Sub Division', 'Vehicle Color',
#        'Vehicle Year', 'Feet From Curb', 'Violation Description', 'Issue Year',
#        'Issue Month'],
#       dtype='object')

# %%
df.shape
# Out:
# (8942957, 28)
